# %% [markdown]
# ## AFTER FEATURE SELECTION

# %%
import pandas as pd
from pycaret.regression import *

# %%
featureselection = pd.read_csv(r"C:\Users\leila\Downloads\pfaproject\house-price-prediction\notebooks\dimensionality reduction\feature_selection_train.csv")

# %%
setup(data=featureselection, target='SalePrice', session_id=123)
# Out:
# <style type="text/css">
# #T_4e9ca_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4e9ca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4e9ca_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4e9ca_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e9ca_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4e9ca_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4e9ca_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_4e9ca_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4e9ca_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4e9ca_row1_col1" class="data row1 col1" >SalePrice</td>
#     </tr>
#     <tr>
#       <th id="T_4e9ca_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_5c5b6 th {
#   text-align: left;
# }
# ...

# %%
model = create_model('lightgbm') 
tuned_model = tune_model(model)
evaluate_model(tuned_model)
# Out:
# <style type="text/css">
# #T_8b33f_row10_col0, #T_8b33f_row10_col1, #T_8b33f_row10_col2, #T_8b33f_row10_col3, #T_8b33f_row10_col4, #T_8b33f_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_8b33f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b33f_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_8b33f_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_8b33f_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_8b33f_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_8b33f_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_8b33f_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
final_model = finalize_model(tuned_model)

# %%
new_data = pd.read_csv(r"C:\Users\leila\Downloads\pfaproject\house-price-prediction\notebooks\dimensionality reduction\feature_selection_test.csv")

# %%
predictions = predict_model(final_model, data=new_data)
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2

# %%
predictions
# Out:
#       LotFrontage  OverallQual  YearBuilt  YearRemodAdd  MasVnrArea  \
# 0        0.526150    -0.751101  -0.340945     -1.072885   -0.563316
# 1        0.573788    -0.054877  -0.439695     -1.214908    0.047057
# 2        0.240326    -0.751101   0.844059      0.678742   -0.563316
# 3        0.430876    -0.054877   0.876976      0.678742   -0.450284
# 4       -1.236435     1.337571   0.679475      0.394694   -0.563316
# ...           ...          ...        ...           ...         ...
# 1454    -2.284458    -1.447325  -0.044694     -0.646813   -0.563316
# 1455    -2.284458    -1.447325  -0.044694     -0.646813   -0.563316
# 1456     4.337145    -0.751101  -0.373861      0.584059   -0.563316
# 1457    -0.331323    -0.751101   0.679475      0.394694   -0.563316
# 1458     0.240326     0.641347   0.712392      0.489377   -0.032066
#
#       ExterQual  BsmtQual  BsmtExposure  BsmtFinSF1  TotalBsmtSF  ...  \
# 0     -0.678101 -0.499340     -0.575738    0.063936    -0.367060  ...
# ...

# %%
save_model(final_model, 'my_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['LotFrontage', 'OverallQual',
#                                               'YearBuilt', 'YearRemodAdd',
#                                               'MasVnrArea', 'ExterQual',
#                                               'BsmtQual', 'BsmtExposure',
#                                               'BsmtFinSF1', 'TotalBsmtSF',
#                                               'HeatingQC', '1stFlrSF',
#                                               'GrLivArea', 'FullBath',
#                                               'KitchenQual', 'TotRmsAbvGrd',
#                                               'Fireplaces', 'GarageFinish',
#                                               'GarageCars', 'Garage...
#                                      transformer=SimpleImputer())),
# ...

# %%
#loading the model
#loaded_model = load_model('my_model')

# %%
#gradio app
create_app(model)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
