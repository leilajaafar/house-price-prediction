# %% [markdown]
# ## CHI SQUARED & CRAMER'S V TEST

# %% [markdown]
# ### FOR CATEGORICAL/QUANTITATIVE FEATURES

# %%
import pandas as pd

# %% [markdown]
# *just cleaned data, not standardized and not encoded.*

# %%
df_train = pd.read_csv(r"C:\Users\leila\Downloads\pfaproject\house-price-prediction\data\raw data\train.csv")

# %%
### 1. Traitement des valeurs manquantes selon la description ###

# Variables catégorielles avec "NA" dans la description
na_categorical = {
    "Alley": "NA",  # No alley access
    "BsmtQual": "NA",  # No Basement
    "BsmtCond": "NA",  # No Basement
    "BsmtExposure": "NA",  # No Basement
    "BsmtFinType1": "NA",  # No Basement
    "BsmtFinType2": "NA",  # No Basement
    "FireplaceQu": "NA",  # No Fireplace
    "GarageType": "NA",  # No Garage
    "GarageFinish": "NA",  # No Garage
    "GarageQual": "NA",  # No Garage
    "GarageCond": "NA",  # No Garage
    "PoolQC": "NA",  # No Pool
    "Fence": "NA",  # No Fence
    "MiscFeature": "NA"  # None
}

for col, na_value in na_categorical.items():
    df_train[col] = df_train[col].fillna(na_value)

# Variables avec "None" comme option valide
none_categorical = {
    "MasVnrType": "None"  # Masonry veneer type
}
for col, none_value in none_categorical.items():
    df_train[col] = df_train[col].fillna(none_value)

# Variables numériques
df_train["LotFrontage"] = df_train.groupby("Neighborhood")["LotFrontage"].transform(lambda x: x.fillna(x.median()))
df_train["MasVnrArea"] = df_train["MasVnrArea"].fillna(0)  # Si pas de maçonnerie
df_train["GarageYrBlt"] = df_train["GarageYrBlt"].fillna(0)  # Si pas de garage

# Electrical - seul NA, utiliser le mode
df_train["Electrical"] = df_train["Electrical"].fillna(df_train["Electrical"].mode()[0])

### 2. Vérification des relations entre variables ###

# Si pas de sous-sol, surfaces = 0
bsmt_cols = ["BsmtFinSF1", "BsmtFinSF2", "BsmtUnfSF", "TotalBsmtSF"]
df_train.loc[df_train["BsmtQual"] == "NA", bsmt_cols] = 0

# Si pas de garage, surfaces = 0
df_train.loc[df_train["GarageType"] == "NA", ["GarageCars", "GarageArea"]] = 0

# Si pas de cheminée
df_train.loc[df_train["Fireplaces"] == 0, "FireplaceQu"] = "NA"

# Si pas de piscine
df_train.loc[df_train["PoolArea"] == 0, "PoolQC"] = "NA"

### 3. Vérification finale ###
print("Valeurs manquantes restantes:")
print(df_train.isnull().sum().sum())
# Out:
# Valeurs manquantes restantes:
# 0

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          1460 non-null   object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     1460 non-null   object
#  26  MasVnrArea     1460 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1460 non-null   object
#  31  BsmtCond       1460 non-null   object
#  32  BsmtExposure   1460 non-null   object
#  33  BsmtFinType1   1460 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1460 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1460 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    1460 non-null   object
#  58  GarageType     1460 non-null   object
#  59  GarageYrBlt    1460 non-null   float64
#  60  GarageFinish   1460 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1460 non-null   object
#  64  GarageCond     1460 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         1460 non-null   object
#  73  Fence          1460 non-null   object
#  74  MiscFeature    1460 non-null   object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %% [markdown]
# *select only categorical*

# %%
categorical_df = df_train.select_dtypes(include=['object', 'bool', 'category'])

# %%
for col in categorical_df.columns:
    categorical_df[col] = categorical_df[col].astype('category')

# %%
from scipy.stats import chi2_contingency
import numpy as np
from itertools import combinations

# Iterate through all pairs of categorical variables
for var1, var2 in combinations(categorical_df.columns, 2):
    contingency_table = pd.crosstab(categorical_df[var1], categorical_df[var2])
    chi2, p, dof, expected = chi2_contingency(contingency_table)
    n = contingency_table.sum().sum()
    min_dim = min(contingency_table.shape) - 1
    cramers_v = np.sqrt(chi2 / (n * min_dim))
    print(f"Cramér's V between {var1} and {var2}: {cramers_v:.4f}")
# Out:
# Cramér's V between MSZoning and Street: 0.2547
# Cramér's V between MSZoning and Alley: 0.3921
# Cramér's V between MSZoning and LotShape: 0.1608
# Cramér's V between MSZoning and LandContour: 0.1147
# Cramér's V between MSZoning and Utilities: 0.0136
# Cramér's V between MSZoning and LotConfig: 0.0825
# Cramér's V between MSZoning and LandSlope: 0.0888
# Cramér's V between MSZoning and Neighborhood: 0.6525
# Cramér's V between MSZoning and Condition1: 0.1027
# Cramér's V between MSZoning and Condition2: 0.0908
# Cramér's V between MSZoning and BldgType: 0.1954
# Cramér's V between MSZoning and HouseStyle: 0.1968
# Cramér's V between MSZoning and RoofStyle: 0.0934
# Cramér's V between MSZoning and RoofMatl: 0.0317
# Cramér's V between MSZoning and Exterior1st: 0.2029
# Cramér's V between MSZoning and Exterior2nd: 0.2119
# Cramér's V between MSZoning and MasVnrType: 0.1112
# Cramér's V between MSZoning and ExterQual: 0.2449
# Cramér's V between MSZoning and ExterCond: 0.0947
# Cramér's V between MSZoning and Foundation: 0.2309
# Cramér's V between MSZoning and BsmtQual: 0.1726
# Cramér's V between MSZoning and BsmtCond: 0.0946
# Cramér's V between MSZoning and BsmtExposure: 0.0830
# Cramér's V between MSZoning and BsmtFinType1: 0.1487
# Cramér's V between MSZoning and BsmtFinType2: 0.0746
# Cramér's V between MSZoning and Heating: 0.0800
# Cramér's V between MSZoning and HeatingQC: 0.1281
# Cramér's V between MSZoning and CentralAir: 0.3011
# Cramér's V between MSZoning and Electrical: 0.1155
# Cramér's V between MSZoning and KitchenQual: 0.1819
# Cramér's V between MSZoning and Functional: 0.0573
# Cramér's V between MSZoning and FireplaceQu: 0.1323
# Cramér's V between MSZoning and GarageType: 0.2206
# Cramér's V between MSZoning and GarageFinish: 0.2005
# Cramér's V between MSZoning and GarageQual: 0.1383
# Cramér's V between MSZoning and GarageCond: 0.1173
# Cramér's V between MSZoning and PavedDrive: 0.2245
# Cramér's V between MSZoning and PoolQC: 0.0208
# Cramér's V between MSZoning and Fence: 0.0582
# Cramér's V between MSZoning and MiscFeature: 0.0499
# Cramér's V between MSZoning and SaleType: 0.1679
# Cramér's V between MSZoning and SaleCondition: 0.1480
# Cramér's V between Street and Alley: 0.0166
# Cramér's V between Street and LotShape: 0.0565
# Cramér's V between Street and LandContour: 0.1225
# Cramér's V between Street and Utilities: 0.0000
# Cramér's V between Street and LotConfig: 0.0310
# Cramér's V between Street and LandSlope: 0.1800
# Cramér's V between Street and Neighborhood: 0.2364
# Cramér's V between Street and Condition1: 0.1807
# Cramér's V between Street and Condition2: 0.0065
# Cramér's V between Street and BldgType: 0.1240
# Cramér's V between Street and HouseStyle: 0.0719
# Cramér's V between Street and RoofStyle: 0.0237
# Cramér's V between Street and RoofMatl: 0.0086
# Cramér's V between Street and Exterior1st: 0.0669
# Cramér's V between Street and Exterior2nd: 0.0662
# Cramér's V between Street and MasVnrType: 0.0212
# Cramér's V between Street and ExterQual: 0.3242
# Cramér's V between Street and ExterCond: 0.0168
# Cramér's V between Street and Foundation: 0.0733
# Cramér's V between Street and BsmtQual: 0.0329
# Cramér's V between Street and BsmtCond: 0.0217
# Cramér's V between Street and BsmtExposure: 0.1016
# Cramér's V between Street and BsmtFinType1: 0.0459
# Cramér's V between Street and BsmtFinType2: 0.1226
# Cramér's V between Street and Heating: 0.0096
# Cramér's V between Street and HeatingQC: 0.0552
# Cramér's V between Street and CentralAir: 0.0482
# Cramér's V between Street and Electrical: 0.0281
# Cramér's V between Street and KitchenQual: 0.0765
# Cramér's V between Street and Functional: 0.0174
# Cramér's V between Street and FireplaceQu: 0.0270
# Cramér's V between Street and GarageType: 0.2321
# Cramér's V between Street and GarageFinish: 0.0333
# Cramér's V between Street and GarageQual: 0.0336
# Cramér's V between Street and GarageCond: 0.0331
# Cramér's V between Street and PavedDrive: 0.0292
# Cramér's V between Street and PoolQC: 0.0045
# Cramér's V between Street and Fence: 0.0314
# Cramér's V between Street and MiscFeature: 0.1664
# Cramér's V between Street and SaleType: 0.1333
# Cramér's V between Street and SaleCondition: 0.1154
# Cramér's V between Alley and LotShape: 0.0917
# Cramér's V between Alley and LandContour: 0.0846
# Cramér's V between Alley and Utilities: 0.0067
# Cramér's V between Alley and LotConfig: 0.0629
# Cramér's V between Alley and LandSlope: 0.0237
# Cramér's V between Alley and Neighborhood: 0.4470
# Cramér's V between Alley and Condition1: 0.1464
# Cramér's V between Alley and Condition2: 0.0186
# Cramér's V between Alley and BldgType: 0.1625
# Cramér's V between Alley and HouseStyle: 0.1583
# Cramér's V between Alley and RoofStyle: 0.1223
# Cramér's V between Alley and RoofMatl: 0.0245
# Cramér's V between Alley and Exterior1st: 0.2290
# Cramér's V between Alley and Exterior2nd: 0.2253
# Cramér's V between Alley and MasVnrType: 0.1029
# Cramér's V between Alley and ExterQual: 0.1183
# Cramér's V between Alley and ExterCond: 0.0676
# Cramér's V between Alley and Foundation: 0.2298
# Cramér's V between Alley and BsmtQual: 0.1412
# Cramér's V between Alley and BsmtCond: 0.0922
# Cramér's V between Alley and BsmtExposure: 0.0978
# Cramér's V between Alley and BsmtFinType1: 0.1292
# Cramér's V between Alley and BsmtFinType2: 0.0624
# Cramér's V between Alley and Heating: 0.1358
# Cramér's V between Alley and HeatingQC: 0.1018
# Cramér's V between Alley and CentralAir: 0.2044
# Cramér's V between Alley and Electrical: 0.1409
# Cramér's V between Alley and KitchenQual: 0.1043
# Cramér's V between Alley and Functional: 0.0724
# Cramér's V between Alley and FireplaceQu: 0.0933
# Cramér's V between Alley and GarageType: 0.2080
# Cramér's V between Alley and GarageFinish: 0.1471
# Cramér's V between Alley and GarageQual: 0.1367
# Cramér's V between Alley and GarageCond: 0.1523
# Cramér's V between Alley and PavedDrive: 0.1826
# Cramér's V between Alley and PoolQC: 0.0127
# Cramér's V between Alley and Fence: 0.0489
# Cramér's V between Alley and MiscFeature: 0.0418
# Cramér's V between Alley and SaleType: 0.0821
# Cramér's V between Alley and SaleCondition: 0.0872
# Cramér's V between LotShape and LandContour: 0.1343
# Cramér's V between LotShape and Utilities: 0.0372
# Cramér's V between LotShape and LotConfig: 0.2269
# Cramér's V between LotShape and LandSlope: 0.1272
# Cramér's V between LotShape and Neighborhood: 0.2755
# Cramér's V between LotShape and Condition1: 0.1281
# Cramér's V between LotShape and Condition2: 0.0608
# Cramér's V between LotShape and BldgType: 0.0993
# Cramér's V between LotShape and HouseStyle: 0.1008
# Cramér's V between LotShape and RoofStyle: 0.0684
# Cramér's V between LotShape and RoofMatl: 0.1980
# Cramér's V between LotShape and Exterior1st: 0.1274
# Cramér's V between LotShape and Exterior2nd: 0.1377
# Cramér's V between LotShape and MasVnrType: 0.0821
# Cramér's V between LotShape and ExterQual: 0.1207
# Cramér's V between LotShape and ExterCond: 0.0513
# Cramér's V between LotShape and Foundation: 0.1303
# Cramér's V between LotShape and BsmtQual: 0.1495
# Cramér's V between LotShape and BsmtCond: 0.0784
# Cramér's V between LotShape and BsmtExposure: 0.1176
# Cramér's V between LotShape and BsmtFinType1: 0.0902
# Cramér's V between LotShape and BsmtFinType2: 0.0913
# Cramér's V between LotShape and Heating: 0.0637
# Cramér's V between LotShape and HeatingQC: 0.0744
# Cramér's V between LotShape and CentralAir: 0.1168
# Cramér's V between LotShape and Electrical: 0.1239
# Cramér's V between LotShape and KitchenQual: 0.1028
# Cramér's V between LotShape and Functional: 0.0383
# Cramér's V between LotShape and FireplaceQu: 0.1356
# Cramér's V between LotShape and GarageType: 0.1564
# Cramér's V between LotShape and GarageFinish: 0.1483
# Cramér's V between LotShape and GarageQual: 0.0958
# Cramér's V between LotShape and GarageCond: 0.0777
# Cramér's V between LotShape and PavedDrive: 0.0880
# Cramér's V between LotShape and PoolQC: 0.1046
# Cramér's V between LotShape and Fence: 0.0604
# Cramér's V between LotShape and MiscFeature: 0.0426
# Cramér's V between LotShape and SaleType: 0.0543
# Cramér's V between LotShape and SaleCondition: 0.0586
# Cramér's V between LandContour and Utilities: 0.0088
# Cramér's V between LandContour and LotConfig: 0.0796
# Cramér's V between LandContour and LandSlope: 0.4592
# Cramér's V between LandContour and Neighborhood: 0.3817
# Cramér's V between LandContour and Condition1: 0.0681
# Cramér's V between LandContour and Condition2: 0.0912
# Cramér's V between LandContour and BldgType: 0.0865
# Cramér's V between LandContour and HouseStyle: 0.1435
# Cramér's V between LandContour and RoofStyle: 0.1521
# Cramér's V between LandContour and RoofMatl: 0.1932
# Cramér's V between LandContour and Exterior1st: 0.1520
# Cramér's V between LandContour and Exterior2nd: 0.1577
# Cramér's V between LandContour and MasVnrType: 0.0987
# Cramér's V between LandContour and ExterQual: 0.1412
# Cramér's V between LandContour and ExterCond: 0.0306
# Cramér's V between LandContour and Foundation: 0.1162
# Cramér's V between LandContour and BsmtQual: 0.1063
# Cramér's V between LandContour and BsmtCond: 0.0803
# Cramér's V between LandContour and BsmtExposure: 0.1992
# Cramér's V between LandContour and BsmtFinType1: 0.1076
# Cramér's V between LandContour and BsmtFinType2: 0.0566
# Cramér's V between LandContour and Heating: 0.0338
# Cramér's V between LandContour and HeatingQC: 0.0752
# Cramér's V between LandContour and CentralAir: 0.1360
# Cramér's V between LandContour and Electrical: 0.0736
# Cramér's V between LandContour and KitchenQual: 0.1070
# Cramér's V between LandContour and Functional: 0.0556
# Cramér's V between LandContour and FireplaceQu: 0.0953
# Cramér's V between LandContour and GarageType: 0.1324
# Cramér's V between LandContour and GarageFinish: 0.1114
# Cramér's V between LandContour and GarageQual: 0.0694
# Cramér's V between LandContour and GarageCond: 0.0552
# Cramér's V between LandContour and PavedDrive: 0.1249
# Cramér's V between LandContour and PoolQC: 0.0390
# Cramér's V between LandContour and Fence: 0.0612
# Cramér's V between LandContour and MiscFeature: 0.0202
# Cramér's V between LandContour and SaleType: 0.0800
# Cramér's V between LandContour and SaleCondition: 0.1220
# Cramér's V between Utilities and LotConfig: 0.0998
# Cramér's V between Utilities and LandSlope: 0.0062
# Cramér's V between Utilities and Neighborhood: 0.1602
# Cramér's V between Utilities and Condition1: 0.0104
# Cramér's V between Utilities and Condition2: 0.0027
# Cramér's V between Utilities and BldgType: 0.0116
# Cramér's V between Utilities and HouseStyle: 0.1213
# Cramér's V between Utilities and RoofStyle: 0.0138
# Cramér's V between Utilities and RoofMatl: 0.0035
# Cramér's V between Utilities and Exterior1st: 0.0618
# Cramér's V between Utilities and Exterior2nd: 0.0644
# Cramér's V between Utilities and MasVnrType: 0.0395
# Cramér's V between Utilities and ExterQual: 0.0205
# Cramér's V between Utilities and ExterCond: 0.0098
# Cramér's V between Utilities and Foundation: 0.0299
# Cramér's V between Utilities and BsmtQual: 0.0293
# Cramér's V between Utilities and BsmtCond: 0.0088
# Cramér's V between Utilities and BsmtExposure: 0.0191
# Cramér's V between Utilities and BsmtFinType1: 0.0413
# Cramér's V between Utilities and BsmtFinType2: 0.1336
# Cramér's V between Utilities and Heating: 0.0039
# Cramér's V between Utilities and HeatingQC: 0.0589
# Cramér's V between Utilities and CentralAir: 0.0000
# Cramér's V between Utilities and Electrical: 0.0998
# Cramér's V between Utilities and KitchenQual: 0.0320
# Cramér's V between Utilities and Functional: 0.0071
# Cramér's V between Utilities and FireplaceQu: 0.0441
# Cramér's V between Utilities and GarageType: 0.2280
# Cramér's V between Utilities and GarageFinish: 0.0411
# Cramér's V between Utilities and GarageQual: 0.0088
# Cramér's V between Utilities and GarageCond: 0.0083
# Cramér's V between Utilities and PavedDrive: 0.0078
# Cramér's V between Utilities and PoolQC: 0.0018
# Cramér's V between Utilities and Fence: 0.0128
# Cramér's V between Utilities and MiscFeature: 0.0051
# Cramér's V between Utilities and SaleType: 0.1503
# Cramér's V between Utilities and SaleCondition: 0.0960
# Cramér's V between LotConfig and LandSlope: 0.0948
# Cramér's V between LotConfig and Neighborhood: 0.1874
# Cramér's V between LotConfig and Condition1: 0.1654
# Cramér's V between LotConfig and Condition2: 0.1147
# Cramér's V between LotConfig and BldgType: 0.0863
# Cramér's V between LotConfig and HouseStyle: 0.0668
# Cramér's V between LotConfig and RoofStyle: 0.0949
# Cramér's V between LotConfig and RoofMatl: 0.1037
# Cramér's V between LotConfig and Exterior1st: 0.1111
# Cramér's V between LotConfig and Exterior2nd: 0.1265
# Cramér's V between LotConfig and MasVnrType: 0.0477
# Cramér's V between LotConfig and ExterQual: 0.0543
# Cramér's V between LotConfig and ExterCond: 0.0406
# Cramér's V between LotConfig and Foundation: 0.0723
# Cramér's V between LotConfig and BsmtQual: 0.0872
# Cramér's V between LotConfig and BsmtCond: 0.0525
# Cramér's V between LotConfig and BsmtExposure: 0.0744
# Cramér's V between LotConfig and BsmtFinType1: 0.0832
# Cramér's V between LotConfig and BsmtFinType2: 0.0453
# Cramér's V between LotConfig and Heating: 0.0440
# Cramér's V between LotConfig and HeatingQC: 0.0533
# Cramér's V between LotConfig and CentralAir: 0.0820
# Cramér's V between LotConfig and Electrical: 0.0529
# Cramér's V between LotConfig and KitchenQual: 0.0508
# Cramér's V between LotConfig and Functional: 0.0406
# Cramér's V between LotConfig and FireplaceQu: 0.0761
# Cramér's V between LotConfig and GarageType: 0.0855
# Cramér's V between LotConfig and GarageFinish: 0.0615
# Cramér's V between LotConfig and GarageQual: 0.0604
# Cramér's V between LotConfig and GarageCond: 0.0780
# Cramér's V between LotConfig and PavedDrive: 0.0599
# Cramér's V between LotConfig and PoolQC: 0.0573
# Cramér's V between LotConfig and Fence: 0.0516
# Cramér's V between LotConfig and MiscFeature: 0.0406
# Cramér's V between LotConfig and SaleType: 0.0679
# Cramér's V between LotConfig and SaleCondition: 0.0677
# Cramér's V between LandSlope and Neighborhood: 0.3400
# Cramér's V between LandSlope and Condition1: 0.0563
# Cramér's V between LandSlope and Condition2: 0.0600
# Cramér's V between LandSlope and BldgType: 0.0586
# Cramér's V between LandSlope and HouseStyle: 0.0675
# Cramér's V between LandSlope and RoofStyle: 0.2627
# Cramér's V between LandSlope and RoofMatl: 0.3202
# Cramér's V between LandSlope and Exterior1st: 0.1656
# Cramér's V between LandSlope and Exterior2nd: 0.1543
# Cramér's V between LandSlope and MasVnrType: 0.0652
# Cramér's V between LandSlope and ExterQual: 0.1040
# Cramér's V between LandSlope and ExterCond: 0.0389
# Cramér's V between LandSlope and Foundation: 0.0767
# Cramér's V between LandSlope and BsmtQual: 0.0348
# Cramér's V between LandSlope and BsmtCond: 0.1431
# Cramér's V between LandSlope and BsmtExposure: 0.2275
# Cramér's V between LandSlope and BsmtFinType1: 0.0764
# Cramér's V between LandSlope and BsmtFinType2: 0.0991
# Cramér's V between LandSlope and Heating: 0.0499
# Cramér's V between LandSlope and HeatingQC: 0.0724
# Cramér's V between LandSlope and CentralAir: 0.0114
# Cramér's V between LandSlope and Electrical: 0.0220
# Cramér's V between LandSlope and KitchenQual: 0.0637
# Cramér's V between LandSlope and Functional: 0.0984
# Cramér's V between LandSlope and FireplaceQu: 0.0667
# Cramér's V between LandSlope and GarageType: 0.1263
# Cramér's V between LandSlope and GarageFinish: 0.0362
# Cramér's V between LandSlope and GarageQual: 0.0212
# Cramér's V between LandSlope and GarageCond: 0.0435
# Cramér's V between LandSlope and PavedDrive: 0.0250
# Cramér's V between LandSlope and PoolQC: 0.0117
# Cramér's V between LandSlope and Fence: 0.0447
# Cramér's V between LandSlope and MiscFeature: 0.0472
# Cramér's V between LandSlope and SaleType: 0.0539
# Cramér's V between LandSlope and SaleCondition: 0.0696
# Cramér's V between Neighborhood and Condition1: 0.2247
# Cramér's V between Neighborhood and Condition2: 0.1286
# Cramér's V between Neighborhood and BldgType: 0.4374
# Cramér's V between Neighborhood and HouseStyle: 0.3201
# Cramér's V between Neighborhood and RoofStyle: 0.2258
# Cramér's V between Neighborhood and RoofMatl: 0.1597
# Cramér's V between Neighborhood and Exterior1st: 0.3144
# Cramér's V between Neighborhood and Exterior2nd: 0.3408
# Cramér's V between Neighborhood and MasVnrType: 0.4008
# Cramér's V between Neighborhood and ExterQual: 0.5014
# Cramér's V between Neighborhood and ExterCond: 0.1995
# Cramér's V between Neighborhood and Foundation: 0.4358
# Cramér's V between Neighborhood and BsmtQual: 0.4823
# Cramér's V between Neighborhood and BsmtCond: 0.1805
# Cramér's V between Neighborhood and BsmtExposure: 0.2746
# Cramér's V between Neighborhood and BsmtFinType1: 0.3162
# Cramér's V between Neighborhood and BsmtFinType2: 0.1999
# Cramér's V between Neighborhood and Heating: 0.1390
# Cramér's V between Neighborhood and HeatingQC: 0.3227
# Cramér's V between Neighborhood and CentralAir: 0.4030
# Cramér's V between Neighborhood and Electrical: 0.2203
# Cramér's V between Neighborhood and KitchenQual: 0.4620
# Cramér's V between Neighborhood and Functional: 0.1525
# Cramér's V between Neighborhood and FireplaceQu: 0.3296
# Cramér's V between Neighborhood and GarageType: 0.3247
# Cramér's V between Neighborhood and GarageFinish: 0.4358
# Cramér's V between Neighborhood and GarageQual: 0.2358
# Cramér's V between Neighborhood and GarageCond: 0.2147
# Cramér's V between Neighborhood and PavedDrive: 0.3346
# Cramér's V between Neighborhood and PoolQC: 0.1381
# Cramér's V between Neighborhood and Fence: 0.2170
# Cramér's V between Neighborhood and MiscFeature: 0.1166
# Cramér's V between Neighborhood and SaleType: 0.2122
# Cramér's V between Neighborhood and SaleCondition: 0.2539
# Cramér's V between Condition1 and Condition2: 0.2223
# Cramér's V between Condition1 and BldgType: 0.1060
# Cramér's V between Condition1 and HouseStyle: 0.1125
# Cramér's V between Condition1 and RoofStyle: 0.1099
# Cramér's V between Condition1 and RoofMatl: 0.1069
# Cramér's V between Condition1 and Exterior1st: 0.1217
# Cramér's V between Condition1 and Exterior2nd: 0.1286
# Cramér's V between Condition1 and MasVnrType: 0.0874
# Cramér's V between Condition1 and ExterQual: 0.1451
# Cramér's V between Condition1 and ExterCond: 0.0765
# Cramér's V between Condition1 and Foundation: 0.1090
# Cramér's V between Condition1 and BsmtQual: 0.1504
# Cramér's V between Condition1 and BsmtCond: 0.0841
# Cramér's V between Condition1 and BsmtExposure: 0.0978
# Cramér's V between Condition1 and BsmtFinType1: 0.0873
# Cramér's V between Condition1 and BsmtFinType2: 0.0779
# Cramér's V between Condition1 and Heating: 0.0630
# Cramér's V between Condition1 and HeatingQC: 0.1734
# Cramér's V between Condition1 and CentralAir: 0.0843
# Cramér's V between Condition1 and Electrical: 0.0843
# Cramér's V between Condition1 and KitchenQual: 0.1110
# Cramér's V between Condition1 and Functional: 0.0673
# Cramér's V between Condition1 and FireplaceQu: 0.0708
# Cramér's V between Condition1 and GarageType: 0.1159
# Cramér's V between Condition1 and GarageFinish: 0.1418
# Cramér's V between Condition1 and GarageQual: 0.0794
# Cramér's V between Condition1 and GarageCond: 0.0801
# Cramér's V between Condition1 and PavedDrive: 0.1268
# Cramér's V between Condition1 and PoolQC: 0.1014
# Cramér's V between Condition1 and Fence: 0.0803
# Cramér's V between Condition1 and MiscFeature: 0.1055
# Cramér's V between Condition1 and SaleType: 0.0814
# Cramér's V between Condition1 and SaleCondition: 0.0679
# Cramér's V between Condition2 and BldgType: 0.1595
# Cramér's V between Condition2 and HouseStyle: 0.1404
# Cramér's V between Condition2 and RoofStyle: 0.3183
# Cramér's V between Condition2 and RoofMatl: 0.0052
# Cramér's V between Condition2 and Exterior1st: 0.1005
# Cramér's V between Condition2 and Exterior2nd: 0.0959
# Cramér's V between Condition2 and MasVnrType: 0.0600
# Cramér's V between Condition2 and ExterQual: 0.1535
# Cramér's V between Condition2 and ExterCond: 0.2920
# Cramér's V between Condition2 and Foundation: 0.0777
# Cramér's V between Condition2 and BsmtQual: 0.1128
# Cramér's V between Condition2 and BsmtCond: 0.0581
# Cramér's V between Condition2 and BsmtExposure: 0.0541
# Cramér's V between Condition2 and BsmtFinType1: 0.0684
# Cramér's V between Condition2 and BsmtFinType2: 0.0677
# Cramér's V between Condition2 and Heating: 0.0068
# Cramér's V between Condition2 and HeatingQC: 0.0976
# Cramér's V between Condition2 and CentralAir: 0.0974
# Cramér's V between Condition2 and Electrical: 0.0185
# Cramér's V between Condition2 and KitchenQual: 0.1135
# Cramér's V between Condition2 and Functional: 0.0113
# Cramér's V between Condition2 and FireplaceQu: 0.0569
# Cramér's V between Condition2 and GarageType: 0.1177
# Cramér's V between Condition2 and GarageFinish: 0.0634
# Cramér's V between Condition2 and GarageQual: 0.1591
# Cramér's V between Condition2 and GarageCond: 0.0609
# Cramér's V between Condition2 and PavedDrive: 0.0901
# Cramér's V between Condition2 and PoolQC: 0.0041
# Cramér's V between Condition2 and Fence: 0.0621
# Cramér's V between Condition2 and MiscFeature: 0.3543
# Cramér's V between Condition2 and SaleType: 0.0692
# Cramér's V between Condition2 and SaleCondition: 0.0639
# Cramér's V between BldgType and HouseStyle: 0.1708
# Cramér's V between BldgType and RoofStyle: 0.0755
# Cramér's V between BldgType and RoofMatl: 0.0744
# Cramér's V between BldgType and Exterior1st: 0.1897
# Cramér's V between BldgType and Exterior2nd: 0.2122
# Cramér's V between BldgType and MasVnrType: 0.1034
# Cramér's V between BldgType and ExterQual: 0.1831
# Cramér's V between BldgType and ExterCond: 0.1216
# Cramér's V between BldgType and Foundation: 0.1971
# Cramér's V between BldgType and BsmtQual: 0.2106
# Cramér's V between BldgType and BsmtCond: 0.1618
# Cramér's V between BldgType and BsmtExposure: 0.1672
# Cramér's V between BldgType and BsmtFinType1: 0.1897
# Cramér's V between BldgType and BsmtFinType2: 0.1617
# Cramér's V between BldgType and Heating: 0.1220
# Cramér's V between BldgType and HeatingQC: 0.1233
# Cramér's V between BldgType and CentralAir: 0.2932
# Cramér's V between BldgType and Electrical: 0.0961
# Cramér's V between BldgType and KitchenQual: 0.1582
# Cramér's V between BldgType and Functional: 0.0842
# Cramér's V between BldgType and FireplaceQu: 0.1121
# Cramér's V between BldgType and GarageType: 0.1881
# Cramér's V between BldgType and GarageFinish: 0.1952
# Cramér's V between BldgType and GarageQual: 0.1356
# Cramér's V between BldgType and GarageCond: 0.1237
# Cramér's V between BldgType and PavedDrive: 0.1561
# Cramér's V between BldgType and PoolQC: 0.0178
# Cramér's V between BldgType and Fence: 0.0820
# Cramér's V between BldgType and MiscFeature: 0.0840
# Cramér's V between BldgType and SaleType: 0.1229
# Cramér's V between BldgType and SaleCondition: 0.1638
# Cramér's V between HouseStyle and RoofStyle: 0.1230
# Cramér's V between HouseStyle and RoofMatl: 0.0836
# Cramér's V between HouseStyle and Exterior1st: 0.1875
# Cramér's V between HouseStyle and Exterior2nd: 0.1948
# Cramér's V between HouseStyle and MasVnrType: 0.1770
# Cramér's V between HouseStyle and ExterQual: 0.1893
# Cramér's V between HouseStyle and ExterCond: 0.1241
# Cramér's V between HouseStyle and Foundation: 0.2264
# Cramér's V between HouseStyle and BsmtQual: 0.1968
# Cramér's V between HouseStyle and BsmtCond: 0.1043
# Cramér's V between HouseStyle and BsmtExposure: 0.2103
# Cramér's V between HouseStyle and BsmtFinType1: 0.1626
# Cramér's V between HouseStyle and BsmtFinType2: 0.0891
# Cramér's V between HouseStyle and Heating: 0.1572
# Cramér's V between HouseStyle and HeatingQC: 0.1816
# Cramér's V between HouseStyle and CentralAir: 0.2432
# Cramér's V between HouseStyle and Electrical: 0.1288
# Cramér's V between HouseStyle and KitchenQual: 0.1621
# Cramér's V between HouseStyle and Functional: 0.0772
# Cramér's V between HouseStyle and FireplaceQu: 0.1286
# Cramér's V between HouseStyle and GarageType: 0.2123
# Cramér's V between HouseStyle and GarageFinish: 0.2154
# Cramér's V between HouseStyle and GarageQual: 0.1593
# Cramér's V between HouseStyle and GarageCond: 0.1461
# Cramér's V between HouseStyle and PavedDrive: 0.1774
# Cramér's V between HouseStyle and PoolQC: 0.0872
# Cramér's V between HouseStyle and Fence: 0.1295
# Cramér's V between HouseStyle and MiscFeature: 0.0516
# Cramér's V between HouseStyle and SaleType: 0.0921
# Cramér's V between HouseStyle and SaleCondition: 0.1101
# Cramér's V between RoofStyle and RoofMatl: 0.4625
# Cramér's V between RoofStyle and Exterior1st: 0.1691
# Cramér's V between RoofStyle and Exterior2nd: 0.1889
# Cramér's V between RoofStyle and MasVnrType: 0.1424
# Cramér's V between RoofStyle and ExterQual: 0.1572
# Cramér's V between RoofStyle and ExterCond: 0.1091
# Cramér's V between RoofStyle and Foundation: 0.1088
# Cramér's V between RoofStyle and BsmtQual: 0.1523
# Cramér's V between RoofStyle and BsmtCond: 0.0705
# Cramér's V between RoofStyle and BsmtExposure: 0.1270
# Cramér's V between RoofStyle and BsmtFinType1: 0.0817
# Cramér's V between RoofStyle and BsmtFinType2: 0.0949
# Cramér's V between RoofStyle and Heating: 0.0555
# Cramér's V between RoofStyle and HeatingQC: 0.0465
# Cramér's V between RoofStyle and CentralAir: 0.0803
# Cramér's V between RoofStyle and Electrical: 0.0332
# Cramér's V between RoofStyle and KitchenQual: 0.1256
# Cramér's V between RoofStyle and Functional: 0.1408
# Cramér's V between RoofStyle and FireplaceQu: 0.1020
# Cramér's V between RoofStyle and GarageType: 0.0932
# Cramér's V between RoofStyle and GarageFinish: 0.1081
# Cramér's V between RoofStyle and GarageQual: 0.0569
# Cramér's V between RoofStyle and GarageCond: 0.0740
# Cramér's V between RoofStyle and PavedDrive: 0.1307
# Cramér's V between RoofStyle and PoolQC: 0.0944
# Cramér's V between RoofStyle and Fence: 0.0591
# Cramér's V between RoofStyle and MiscFeature: 0.2521
# Cramér's V between RoofStyle and SaleType: 0.0490
# Cramér's V between RoofStyle and SaleCondition: 0.1057
# Cramér's V between RoofMatl and Exterior1st: 0.2102
# Cramér's V between RoofMatl and Exterior2nd: 0.1536
# Cramér's V between RoofMatl and MasVnrType: 0.0859
# Cramér's V between RoofMatl and ExterQual: 0.0956
# Cramér's V between RoofMatl and ExterCond: 0.0421
# Cramér's V between RoofMatl and Foundation: 0.0490
# Cramér's V between RoofMatl and BsmtQual: 0.0723
# Cramér's V between RoofMatl and BsmtCond: 0.0726
# Cramér's V between RoofMatl and BsmtExposure: 0.1404
# Cramér's V between RoofMatl and BsmtFinType1: 0.0784
# Cramér's V between RoofMatl and BsmtFinType2: 0.1203
# Cramér's V between RoofMatl and Heating: 0.0288
# Cramér's V between RoofMatl and HeatingQC: 0.0565
# Cramér's V between RoofMatl and CentralAir: 0.0283
# Cramér's V between RoofMatl and Electrical: 0.0581
# Cramér's V between RoofMatl and KitchenQual: 0.0790
# Cramér's V between RoofMatl and Functional: 0.1676
# Cramér's V between RoofMatl and FireplaceQu: 0.0859
# Cramér's V between RoofMatl and GarageType: 0.0590
# Cramér's V between RoofMatl and GarageFinish: 0.0611
# Cramér's V between RoofMatl and GarageQual: 0.1107
# Cramér's V between RoofMatl and GarageCond: 0.0890
# Cramér's V between RoofMatl and PavedDrive: 0.0285
# Cramér's V between RoofMatl and PoolQC: 0.3477
# Cramér's V between RoofMatl and Fence: 0.0570
# Cramér's V between RoofMatl and MiscFeature: 0.0132
# Cramér's V between RoofMatl and SaleType: 0.0437
# Cramér's V between RoofMatl and SaleCondition: 0.0894
# Cramér's V between Exterior1st and Exterior2nd: 0.7620
# Cramér's V between Exterior1st and MasVnrType: 0.2429
# Cramér's V between Exterior1st and ExterQual: 0.3637
# Cramér's V between Exterior1st and ExterCond: 0.1364
# Cramér's V between Exterior1st and Foundation: 0.3290
# Cramér's V between Exterior1st and BsmtQual: 0.3128
# Cramér's V between Exterior1st and BsmtCond: 0.1670
# Cramér's V between Exterior1st and BsmtExposure: 0.1791
# Cramér's V between Exterior1st and BsmtFinType1: 0.2340
# Cramér's V between Exterior1st and BsmtFinType2: 0.1762
# Cramér's V between Exterior1st and Heating: 0.1658
# Cramér's V between Exterior1st and HeatingQC: 0.2828
# Cramér's V between Exterior1st and CentralAir: 0.3622
# Cramér's V between Exterior1st and Electrical: 0.2261
# Cramér's V between Exterior1st and KitchenQual: 0.3059
# Cramér's V between Exterior1st and Functional: 0.1349
# Cramér's V between Exterior1st and FireplaceQu: 0.1993
# Cramér's V between Exterior1st and GarageType: 0.2165
# Cramér's V between Exterior1st and GarageFinish: 0.2960
# Cramér's V between Exterior1st and GarageQual: 0.1506
# Cramér's V between Exterior1st and GarageCond: 0.1602
# Cramér's V between Exterior1st and PavedDrive: 0.2134
# Cramér's V between Exterior1st and PoolQC: 0.1295
# Cramér's V between Exterior1st and Fence: 0.1601
# Cramér's V between Exterior1st and MiscFeature: 0.0853
# Cramér's V between Exterior1st and SaleType: 0.1538
# Cramér's V between Exterior1st and SaleCondition: 0.1990
# Cramér's V between Exterior2nd and MasVnrType: 0.2365
# Cramér's V between Exterior2nd and ExterQual: 0.3691
# Cramér's V between Exterior2nd and ExterCond: 0.1217
# Cramér's V between Exterior2nd and Foundation: 0.3294
# Cramér's V between Exterior2nd and BsmtQual: 0.3009
# Cramér's V between Exterior2nd and BsmtCond: 0.1472
# Cramér's V between Exterior2nd and BsmtExposure: 0.1778
# Cramér's V between Exterior2nd and BsmtFinType1: 0.2338
# Cramér's V between Exterior2nd and BsmtFinType2: 0.1561
# Cramér's V between Exterior2nd and Heating: 0.2015
# Cramér's V between Exterior2nd and HeatingQC: 0.2838
# Cramér's V between Exterior2nd and CentralAir: 0.3455
# Cramér's V between Exterior2nd and Electrical: 0.2062
# Cramér's V between Exterior2nd and KitchenQual: 0.3016
# Cramér's V between Exterior2nd and Functional: 0.1332
# Cramér's V between Exterior2nd and FireplaceQu: 0.1716
# Cramér's V between Exterior2nd and GarageType: 0.2183
# Cramér's V between Exterior2nd and GarageFinish: 0.2905
# Cramér's V between Exterior2nd and GarageQual: 0.1398
# Cramér's V between Exterior2nd and GarageCond: 0.1413
# Cramér's V between Exterior2nd and PavedDrive: 0.2017
# Cramér's V between Exterior2nd and PoolQC: 0.1759
# Cramér's V between Exterior2nd and Fence: 0.1487
# Cramér's V between Exterior2nd and MiscFeature: 0.0989
# Cramér's V between Exterior2nd and SaleType: 0.1547
# Cramér's V between Exterior2nd and SaleCondition: 0.1927
# Cramér's V between MasVnrType and ExterQual: 0.2484
# Cramér's V between MasVnrType and ExterCond: 0.0820
# Cramér's V between MasVnrType and Foundation: 0.2154
# Cramér's V between MasVnrType and BsmtQual: 0.2573
# Cramér's V between MasVnrType and BsmtCond: 0.0787
# Cramér's V between MasVnrType and BsmtExposure: 0.1363
# Cramér's V between MasVnrType and BsmtFinType1: 0.2080
# Cramér's V between MasVnrType and BsmtFinType2: 0.0959
# Cramér's V between MasVnrType and Heating: 0.0569
# Cramér's V between MasVnrType and HeatingQC: 0.1610
# Cramér's V between MasVnrType and CentralAir: 0.1833
# Cramér's V between MasVnrType and Electrical: 0.0961
# Cramér's V between MasVnrType and KitchenQual: 0.2257
# Cramér's V between MasVnrType and Functional: 0.1800
# Cramér's V between MasVnrType and FireplaceQu: 0.2082
# Cramér's V between MasVnrType and GarageType: 0.2383
# Cramér's V between MasVnrType and GarageFinish: 0.2228
# Cramér's V between MasVnrType and GarageQual: 0.1346
# Cramér's V between MasVnrType and GarageCond: 0.1234
# Cramér's V between MasVnrType and PavedDrive: 0.1539
# Cramér's V between MasVnrType and PoolQC: 0.0452
# Cramér's V between MasVnrType and Fence: 0.0924
# Cramér's V between MasVnrType and MiscFeature: 0.0596
# Cramér's V between MasVnrType and SaleType: 0.1993
# Cramér's V between MasVnrType and SaleCondition: 0.2039
# Cramér's V between ExterQual and ExterCond: 0.1889
# Cramér's V between ExterQual and Foundation: 0.3753
# Cramér's V between ExterQual and BsmtQual: 0.4668
# Cramér's V between ExterQual and BsmtCond: 0.1762
# Cramér's V between ExterQual and BsmtExposure: 0.1762
# Cramér's V between ExterQual and BsmtFinType1: 0.3041
# Cramér's V between ExterQual and BsmtFinType2: 0.1299
# Cramér's V between ExterQual and Heating: 0.0723
# Cramér's V between ExterQual and HeatingQC: 0.3275
# Cramér's V between ExterQual and CentralAir: 0.2819
# Cramér's V between ExterQual and Electrical: 0.1478
# Cramér's V between ExterQual and KitchenQual: 0.5474
# Cramér's V between ExterQual and Functional: 0.1204
# Cramér's V between ExterQual and FireplaceQu: 0.2470
# Cramér's V between ExterQual and GarageType: 0.2952
# Cramér's V between ExterQual and GarageFinish: 0.3416
# Cramér's V between ExterQual and GarageQual: 0.1618
# Cramér's V between ExterQual and GarageCond: 0.1640
# Cramér's V between ExterQual and PavedDrive: 0.1978
# Cramér's V between ExterQual and PoolQC: 0.0547
# Cramér's V between ExterQual and Fence: 0.1634
# Cramér's V between ExterQual and MiscFeature: 0.1232
# Cramér's V between ExterQual and SaleType: 0.2702
# Cramér's V between ExterQual and SaleCondition: 0.2426
# Cramér's V between ExterCond and Foundation: 0.1360
# Cramér's V between ExterCond and BsmtQual: 0.1168
# Cramér's V between ExterCond and BsmtCond: 0.1939
# Cramér's V between ExterCond and BsmtExposure: 0.0669
# Cramér's V between ExterCond and BsmtFinType1: 0.0994
# Cramér's V between ExterCond and BsmtFinType2: 0.0648
# Cramér's V between ExterCond and Heating: 0.0745
# Cramér's V between ExterCond and HeatingQC: 0.0810
# Cramér's V between ExterCond and CentralAir: 0.2065
# Cramér's V between ExterCond and Electrical: 0.1385
# Cramér's V between ExterCond and KitchenQual: 0.1850
# Cramér's V between ExterCond and Functional: 0.1729
# Cramér's V between ExterCond and FireplaceQu: 0.0596
# Cramér's V between ExterCond and GarageType: 0.1298
# Cramér's V between ExterCond and GarageFinish: 0.1526
# Cramér's V between ExterCond and GarageQual: 0.1739
# Cramér's V between ExterCond and GarageCond: 0.1419
# Cramér's V between ExterCond and PavedDrive: 0.1629
# Cramér's V between ExterCond and PoolQC: 0.0361
# Cramér's V between ExterCond and Fence: 0.0984
# Cramér's V between ExterCond and MiscFeature: 0.0998
# Cramér's V between ExterCond and SaleType: 0.1167
# Cramér's V between ExterCond and SaleCondition: 0.0778
# Cramér's V between Foundation and BsmtQual: 0.5339
# Cramér's V between Foundation and BsmtCond: 0.4209
# Cramér's V between Foundation and BsmtExposure: 0.4133
# Cramér's V between Foundation and BsmtFinType1: 0.4582
# Cramér's V between Foundation and BsmtFinType2: 0.3744
# Cramér's V between Foundation and Heating: 0.2237
# Cramér's V between Foundation and HeatingQC: 0.2979
# Cramér's V between Foundation and CentralAir: 0.3695
# Cramér's V between Foundation and Electrical: 0.1908
# Cramér's V between Foundation and KitchenQual: 0.3476
# Cramér's V between Foundation and Functional: 0.1195
# Cramér's V between Foundation and FireplaceQu: 0.1288
# Cramér's V between Foundation and GarageType: 0.2431
# Cramér's V between Foundation and GarageFinish: 0.3127
# Cramér's V between Foundation and GarageQual: 0.2006
# Cramér's V between Foundation and GarageCond: 0.1478
# Cramér's V between Foundation and PavedDrive: 0.2431
# Cramér's V between Foundation and PoolQC: 0.0368
# Cramér's V between Foundation and Fence: 0.1478
# Cramér's V between Foundation and MiscFeature: 0.1022
# Cramér's V between Foundation and SaleType: 0.1667
# Cramér's V between Foundation and SaleCondition: 0.1680
# Cramér's V between BsmtQual and BsmtCond: 0.5286
# Cramér's V between BsmtQual and BsmtExposure: 0.5228
# Cramér's V between BsmtQual and BsmtFinType1: 0.5794
# Cramér's V between BsmtQual and BsmtFinType2: 0.5034
# Cramér's V between BsmtQual and Heating: 0.1878
# Cramér's V between BsmtQual and HeatingQC: 0.2467
# Cramér's V between BsmtQual and CentralAir: 0.2884
# Cramér's V between BsmtQual and Electrical: 0.2061
# Cramér's V between BsmtQual and KitchenQual: 0.4252
# Cramér's V between BsmtQual and Functional: 0.1295
# Cramér's V between BsmtQual and FireplaceQu: 0.2485
# Cramér's V between BsmtQual and GarageType: 0.2503
# Cramér's V between BsmtQual and GarageFinish: 0.3444
# Cramér's V between BsmtQual and GarageQual: 0.1747
# Cramér's V between BsmtQual and GarageCond: 0.1617
# Cramér's V between BsmtQual and PavedDrive: 0.2011
# Cramér's V between BsmtQual and PoolQC: 0.0429
# Cramér's V between BsmtQual and Fence: 0.1430
# Cramér's V between BsmtQual and MiscFeature: 0.0744
# Cramér's V between BsmtQual and SaleType: 0.2234
# Cramér's V between BsmtQual and SaleCondition: 0.2320
# Cramér's V between BsmtCond and BsmtExposure: 0.4971
# Cramér's V between BsmtCond and BsmtFinType1: 0.5103
# Cramér's V between BsmtCond and BsmtFinType2: 0.4979
# Cramér's V between BsmtCond and Heating: 0.1959
# Cramér's V between BsmtCond and HeatingQC: 0.1152
# Cramér's V between BsmtCond and CentralAir: 0.3195
# Cramér's V between BsmtCond and Electrical: 0.3815
# Cramér's V between BsmtCond and KitchenQual: 0.1479
# Cramér's V between BsmtCond and Functional: 0.2121
# Cramér's V between BsmtCond and FireplaceQu: 0.0743
# Cramér's V between BsmtCond and GarageType: 0.1298
# Cramér's V between BsmtCond and GarageFinish: 0.1345
# Cramér's V between BsmtCond and GarageQual: 0.2213
# Cramér's V between BsmtCond and GarageCond: 0.1865
# Cramér's V between BsmtCond and PavedDrive: 0.1769
# Cramér's V between BsmtCond and PoolQC: 0.0135
# Cramér's V between BsmtCond and Fence: 0.0345
# Cramér's V between BsmtCond and MiscFeature: 0.0577
# Cramér's V between BsmtCond and SaleType: 0.1035
# Cramér's V between BsmtCond and SaleCondition: 0.1103
# Cramér's V between BsmtExposure and BsmtFinType1: 0.5248
# Cramér's V between BsmtExposure and BsmtFinType2: 0.4941
# Cramér's V between BsmtExposure and Heating: 0.1834
# Cramér's V between BsmtExposure and HeatingQC: 0.1083
# Cramér's V between BsmtExposure and CentralAir: 0.2173
# Cramér's V between BsmtExposure and Electrical: 0.1208
# Cramér's V between BsmtExposure and KitchenQual: 0.1597
# Cramér's V between BsmtExposure and Functional: 0.0900
# Cramér's V between BsmtExposure and FireplaceQu: 0.1059
# Cramér's V between BsmtExposure and GarageType: 0.1526
# Cramér's V between BsmtExposure and GarageFinish: 0.1666
# Cramér's V between BsmtExposure and GarageQual: 0.0840
# Cramér's V between BsmtExposure and GarageCond: 0.0872
# Cramér's V between BsmtExposure and PavedDrive: 0.1234
# Cramér's V between BsmtExposure and PoolQC: 0.0536
# Cramér's V between BsmtExposure and Fence: 0.0502
# Cramér's V between BsmtExposure and MiscFeature: 0.0668
# Cramér's V between BsmtExposure and SaleType: 0.1176
# Cramér's V between BsmtExposure and SaleCondition: 0.1257
# Cramér's V between BsmtFinType1 and BsmtFinType2: 0.4502
# Cramér's V between BsmtFinType1 and Heating: 0.1763
# Cramér's V between BsmtFinType1 and HeatingQC: 0.2194
# Cramér's V between BsmtFinType1 and CentralAir: 0.2671
# Cramér's V between BsmtFinType1 and Electrical: 0.1512
# Cramér's V between BsmtFinType1 and KitchenQual: 0.2891
# Cramér's V between BsmtFinType1 and Functional: 0.1180
# Cramér's V between BsmtFinType1 and FireplaceQu: 0.1390
# Cramér's V between BsmtFinType1 and GarageType: 0.1679
# Cramér's V between BsmtFinType1 and GarageFinish: 0.2321
# Cramér's V between BsmtFinType1 and GarageQual: 0.1046
# Cramér's V between BsmtFinType1 and GarageCond: 0.1030
# Cramér's V between BsmtFinType1 and PavedDrive: 0.2017
# Cramér's V between BsmtFinType1 and PoolQC: 0.0540
# Cramér's V between BsmtFinType1 and Fence: 0.1314
# Cramér's V between BsmtFinType1 and MiscFeature: 0.0940
# Cramér's V between BsmtFinType1 and SaleType: 0.1193
# Cramér's V between BsmtFinType1 and SaleCondition: 0.1365
# Cramér's V between BsmtFinType2 and Heating: 0.1630
# Cramér's V between BsmtFinType2 and HeatingQC: 0.1195
# Cramér's V between BsmtFinType2 and CentralAir: 0.2086
# Cramér's V between BsmtFinType2 and Electrical: 0.1065
# Cramér's V between BsmtFinType2 and KitchenQual: 0.1090
# Cramér's V between BsmtFinType2 and Functional: 0.1129
# Cramér's V between BsmtFinType2 and FireplaceQu: 0.0807
# Cramér's V between BsmtFinType2 and GarageType: 0.1005
# Cramér's V between BsmtFinType2 and GarageFinish: 0.1069
# Cramér's V between BsmtFinType2 and GarageQual: 0.0784
# Cramér's V between BsmtFinType2 and GarageCond: 0.0805
# Cramér's V between BsmtFinType2 and PavedDrive: 0.1138
# Cramér's V between BsmtFinType2 and PoolQC: 0.1322
# Cramér's V between BsmtFinType2 and Fence: 0.1093
# Cramér's V between BsmtFinType2 and MiscFeature: 0.1066
# Cramér's V between BsmtFinType2 and SaleType: 0.0918
# Cramér's V between BsmtFinType2 and SaleCondition: 0.0918
# Cramér's V between Heating and HeatingQC: 0.2453
# Cramér's V between Heating and CentralAir: 0.4644
# Cramér's V between Heating and Electrical: 0.1441
# Cramér's V between Heating and KitchenQual: 0.1653
# Cramér's V between Heating and Functional: 0.0885
# Cramér's V between Heating and FireplaceQu: 0.0519
# Cramér's V between Heating and GarageType: 0.1145
# Cramér's V between Heating and GarageFinish: 0.1236
# Cramér's V between Heating and GarageQual: 0.1396
# Cramér's V between Heating and GarageCond: 0.1774
# Cramér's V between Heating and PavedDrive: 0.1583
# Cramér's V between Heating and PoolQC: 0.0060
# Cramér's V between Heating and Fence: 0.0430
# Cramér's V between Heating and MiscFeature: 0.0122
# Cramér's V between Heating and SaleType: 0.0979
# Cramér's V between Heating and SaleCondition: 0.0343
# Cramér's V between HeatingQC and CentralAir: 0.3822
# Cramér's V between HeatingQC and Electrical: 0.1532
# Cramér's V between HeatingQC and KitchenQual: 0.3223
# Cramér's V between HeatingQC and Functional: 0.0681
# Cramér's V between HeatingQC and FireplaceQu: 0.1297
# Cramér's V between HeatingQC and GarageType: 0.1708
# Cramér's V between HeatingQC and GarageFinish: 0.2464
# Cramér's V between HeatingQC and GarageQual: 0.1101
# Cramér's V between HeatingQC and GarageCond: 0.1131
# Cramér's V between HeatingQC and PavedDrive: 0.1823
# Cramér's V between HeatingQC and PoolQC: 0.0656
# Cramér's V between HeatingQC and Fence: 0.1173
# Cramér's V between HeatingQC and MiscFeature: 0.0613
# Cramér's V between HeatingQC and SaleType: 0.1509
# Cramér's V between HeatingQC and SaleCondition: 0.1600
# Cramér's V between CentralAir and Electrical: 0.4243
# Cramér's V between CentralAir and KitchenQual: 0.3455
# Cramér's V between CentralAir and Functional: 0.1092
# Cramér's V between CentralAir and FireplaceQu: 0.2043
# Cramér's V between CentralAir and GarageType: 0.3658
# Cramér's V between CentralAir and GarageFinish: 0.3286
# Cramér's V between CentralAir and GarageQual: 0.3247
# Cramér's V between CentralAir and GarageCond: 0.3575
# Cramér's V between CentralAir and PavedDrive: 0.3376
# Cramér's V between CentralAir and PoolQC: 0.0183
# Cramér's V between CentralAir and Fence: 0.0508
# Cramér's V between CentralAir and MiscFeature: 0.0664
# Cramér's V between CentralAir and SaleType: 0.1476
# Cramér's V between CentralAir and SaleCondition: 0.1271
# Cramér's V between Electrical and KitchenQual: 0.2081
# Cramér's V between Electrical and Functional: 0.2292
# Cramér's V between Electrical and FireplaceQu: 0.0862
# Cramér's V between Electrical and GarageType: 0.1384
# Cramér's V between Electrical and GarageFinish: 0.1562
# Cramér's V between Electrical and GarageQual: 0.3484
# Cramér's V between Electrical and GarageCond: 0.2439
# Cramér's V between Electrical and PavedDrive: 0.1998
# Cramér's V between Electrical and PoolQC: 0.0123
# Cramér's V between Electrical and Fence: 0.0363
# Cramér's V between Electrical and MiscFeature: 0.0190
# Cramér's V between Electrical and SaleType: 0.0581
# Cramér's V between Electrical and SaleCondition: 0.1696
# Cramér's V between KitchenQual and Functional: 0.1067
# Cramér's V between KitchenQual and FireplaceQu: 0.2641
# Cramér's V between KitchenQual and GarageType: 0.2724
# Cramér's V between KitchenQual and GarageFinish: 0.3229
# Cramér's V between KitchenQual and GarageQual: 0.1962
# Cramér's V between KitchenQual and GarageCond: 0.1954
# Cramér's V between KitchenQual and PavedDrive: 0.1965
# Cramér's V between KitchenQual and PoolQC: 0.0543
# Cramér's V between KitchenQual and Fence: 0.1269
# Cramér's V between KitchenQual and MiscFeature: 0.0900
# Cramér's V between KitchenQual and SaleType: 0.2216
# Cramér's V between KitchenQual and SaleCondition: 0.2193
# Cramér's V between Functional and FireplaceQu: 0.1147
# Cramér's V between Functional and GarageType: 0.1555
# Cramér's V between Functional and GarageFinish: 0.0995
# Cramér's V between Functional and GarageQual: 0.1282
# Cramér's V between Functional and GarageCond: 0.0920
# Cramér's V between Functional and PavedDrive: 0.0983
# Cramér's V between Functional and PoolQC: 0.0109
# Cramér's V between Functional and Fence: 0.0830
# Cramér's V between Functional and MiscFeature: 0.1106
# Cramér's V between Functional and SaleType: 0.0770
# Cramér's V between Functional and SaleCondition: 0.0701
# Cramér's V between FireplaceQu and GarageType: 0.1915
# Cramér's V between FireplaceQu and GarageFinish: 0.2405
# Cramér's V between FireplaceQu and GarageQual: 0.1124
# Cramér's V between FireplaceQu and GarageCond: 0.1115
# Cramér's V between FireplaceQu and PavedDrive: 0.1338
# Cramér's V between FireplaceQu and PoolQC: 0.1350
# Cramér's V between FireplaceQu and Fence: 0.0922
# Cramér's V between FireplaceQu and MiscFeature: 0.0594
# Cramér's V between FireplaceQu and SaleType: 0.1455
# Cramér's V between FireplaceQu and SaleCondition: 0.1334
# Cramér's V between GarageType and GarageFinish: 0.6872
# Cramér's V between GarageType and GarageQual: 0.4628
# Cramér's V between GarageType and GarageCond: 0.4633
# Cramér's V between GarageType and PavedDrive: 0.2952
# Cramér's V between GarageType and PoolQC: 0.0307
# Cramér's V between GarageType and Fence: 0.0991
# Cramér's V between GarageType and MiscFeature: 0.0711
# Cramér's V between GarageType and SaleType: 0.1245
# Cramér's V between GarageType and SaleCondition: 0.1534
# Cramér's V between GarageFinish and GarageQual: 0.5912
# Cramér's V between GarageFinish and GarageCond: 0.5887
# Cramér's V between GarageFinish and PavedDrive: 0.2728
# Cramér's V between GarageFinish and PoolQC: 0.0467
# Cramér's V between GarageFinish and Fence: 0.1095
# Cramér's V between GarageFinish and MiscFeature: 0.0636
# Cramér's V between GarageFinish and SaleType: 0.1859
# Cramér's V between GarageFinish and SaleCondition: 0.1951
# Cramér's V between GarageQual and GarageCond: 0.7055
# Cramér's V between GarageQual and PavedDrive: 0.2869
# Cramér's V between GarageQual and PoolQC: 0.0878
# Cramér's V between GarageQual and Fence: 0.0555
# Cramér's V between GarageQual and MiscFeature: 0.0596
# Cramér's V between GarageQual and SaleType: 0.0780
# Cramér's V between GarageQual and SaleCondition: 0.1025
# Cramér's V between GarageCond and PavedDrive: 0.3078
# Cramér's V between GarageCond and PoolQC: 0.1101
# Cramér's V between GarageCond and Fence: 0.1023
# Cramér's V between GarageCond and MiscFeature: 0.0622
# Cramér's V between GarageCond and SaleType: 0.0855
# Cramér's V between GarageCond and SaleCondition: 0.1045
# Cramér's V between PavedDrive and PoolQC: 0.0147
# Cramér's V between PavedDrive and Fence: 0.0453
# Cramér's V between PavedDrive and MiscFeature: 0.0687
# Cramér's V between PavedDrive and SaleType: 0.1015
# Cramér's V between PavedDrive and SaleCondition: 0.1208
# Cramér's V between PoolQC and Fence: 0.1177
# Cramér's V between PoolQC and MiscFeature: 0.4082
# Cramér's V between PoolQC and SaleType: 0.0268
# Cramér's V between PoolQC and SaleCondition: 0.1258
# Cramér's V between Fence and MiscFeature: 0.0768
# Cramér's V between Fence and SaleType: 0.0931
# Cramér's V between Fence and SaleCondition: 0.0925
# Cramér's V between MiscFeature and SaleType: 0.0584
# Cramér's V between MiscFeature and SaleCondition: 0.0367
# Cramér's V between SaleType and SaleCondition: 0.4758

# %%
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency
from itertools import combinations

# Define a function to compute Cramér's V
def cramers_v(x, y):
    contingency_table = pd.crosstab(x, y)
    chi2, p, dof, expected = chi2_contingency(contingency_table)
    n = contingency_table.sum().sum()
    min_dim = min(contingency_table.shape) - 1
    if min_dim == 0:
        return np.nan  # Avoid division by zero
    return np.sqrt(chi2 / (n * min_dim))

# Assuming 'categorical_df' is your DataFrame with categorical variables
# If not already defined, you can create it as follows:
# categorical_df = df.select_dtypes(include=['object', 'category', 'bool'])

# Compute Cramér's V for all pairs of categorical variables
results = []
for var1, var2 in combinations(categorical_df.columns, 2):
    v = cramers_v(categorical_df[var1], categorical_df[var2])
    if not np.isnan(v):
        results.append({'Variable 1': var1, 'Variable 2': var2, "Cramér's V": v})

# Create a DataFrame with the results
cramers_df = pd.DataFrame(results)

# Sort the DataFrame by Cramér's V in descending order and select the top 20 pairs
top_20 = cramers_df.sort_values(by="Cramér's V", ascending=False).head(20)

# Display the top 20 pairs
print(top_20)
# Out:
#        Variable 1     Variable 2  Cramér's V
# 525   Exterior1st    Exterior2nd    0.762010
# 875    GarageQual     GarageCond    0.705464
# 858    GarageType   GarageFinish    0.687219
# 7        MSZoning   Neighborhood    0.652480
# 867  GarageFinish     GarageQual    0.591226
# 868  GarageFinish     GarageCond    0.588688
# 674      BsmtQual   BsmtFinType1    0.579381
# 614     ExterQual    KitchenQual    0.547358
# 650    Foundation       BsmtQual    0.533869
# 672      BsmtQual       BsmtCond    0.528628
# 713  BsmtExposure   BsmtFinType1    0.524791
# 673      BsmtQual   BsmtExposure    0.522787
# 694      BsmtCond   BsmtFinType1    0.510317
# 675      BsmtQual   BsmtFinType2    0.503431
# 317  Neighborhood      ExterQual    0.501422
# 695      BsmtCond   BsmtFinType2    0.497917
# 693      BsmtCond   BsmtExposure    0.497112
# 714  BsmtExposure   BsmtFinType2    0.494108
# 320  Neighborhood       BsmtQual    0.482304
# 902      SaleType  SaleCondition    0.475809

# %%
from sklearn.feature_selection import chi2
from sklearn.preprocessing import LabelEncoder
import pandas as pd

categorical_df['SalePrice'] = df_train['SalePrice']

X = categorical_df
y = df_train['SalePrice']

# Assuming X is your feature DataFrame and y is the target variable
# Encode categorical variables
X_encoded = X.apply(LabelEncoder().fit_transform)
chi_scores, p_values = chi2(X_encoded, y)

# Create a DataFrame with scores
chi2_df = pd.DataFrame({'Feature': X.columns, 'Chi2 Score': chi_scores, 'p-value': p_values})
chi2_df.sort_values('Chi2 Score', ascending=False, inplace=True)

# %%
chi2_df
# Out:
#           Feature     Chi2 Score        p-value
# 43      SalePrice  143517.249363   0.000000e+00
# 8    Neighborhood    2194.267106  3.242308e-163
# 11       BldgType    1951.478245  2.818820e-127
# 27      HeatingQC    1483.144925   7.831579e-65
# 33     GarageType    1264.929866   3.419318e-40
# 24   BsmtFinType1    1038.132199   3.800022e-19
# 7       LandSlope     889.793781   6.859676e-09
# 12     HouseStyle     812.887720   5.096798e-05
# 16    Exterior2nd     808.619925   7.736118e-05
# 3        LotShape     802.972897   1.326098e-04
# 15    Exterior1st     696.025906   1.741724e-01
# 34   GarageFinish     654.188110   5.781643e-01
# 23   BsmtExposure     643.684248   6.878324e-01
# 21       BsmtQual     589.773663   9.795048e-01
# 6       LotConfig     564.633630   9.974532e-01
# 13      RoofStyle     356.053615   1.000000e+00
# 32    FireplaceQu     313.150586   1.000000e+00
# 30    KitchenQual     303.823780   1.000000e+00
# 20     Foundation     302.333392   1.000000e+00
# 5       Utilities     242.333333   1.000000e+00
# 14       RoofMatl     229.029740   1.000000e+00
# 29     Electrical     213.371047   1.000000e+00
# 9      Condition1     212.616289   1.000000e+00
# 42  SaleCondition     212.586578   1.000000e+00
# 18      ExterQual     209.777237   1.000000e+00
# 39          Fence     197.353025   1.000000e+00
# 41       SaleType     187.470404   1.000000e+00
# 22       BsmtCond     168.516571   1.000000e+00
# 17     MasVnrType     161.240019   1.000000e+00
# 25   BsmtFinType2     155.381146   1.000000e+00
# 35     GarageQual     124.601231   1.000000e+00
# 4     LandContour     124.357379   1.000000e+00
# 0        MSZoning     113.803139   1.000000e+00
# 31     Functional      97.519754   1.000000e+00
# 37     PavedDrive      93.289255   1.000000e+00
# 36     GarageCond      92.753537   1.000000e+00
# 19      ExterCond      87.769596   1.000000e+00
# 40    MiscFeature      80.390246   1.000000e+00
# 26        Heating      67.613241   1.000000e+00
# 28     CentralAir      53.802335   1.000000e+00
# 2           Alley      39.897431   1.000000e+00
# 10     Condition2      27.336481   1.000000e+00
# 38         PoolQC       4.187336   1.000000e+00
# 1          Street       3.650601   1.000000e+00

# %%
from sklearn.feature_selection import mutual_info_classif

mi_scores = mutual_info_classif(X_encoded, y)
mi_df = pd.DataFrame({'Feature': X.columns, 'MI Score': mi_scores})
mi_df.sort_values('MI Score', ascending=False, inplace=True)

# %%
mi_df
# Out:
#           Feature  MI Score
# 43      SalePrice  5.857637
# 1          Street  3.150541
# 10     Condition2  3.051202
# 14       RoofMatl  3.024798
# 38         PoolQC  3.023505
# 40    MiscFeature  2.993597
# 26        Heating  2.991995
# 37     PavedDrive  2.775116
# 31     Functional  2.750548
# 28     CentralAir  2.737914
# 2           Alley  2.720686
# 36     GarageCond  2.679108
# 22       BsmtCond  2.583717
# 41       SaleType  2.578726
# 29     Electrical  2.561530
# 4     LandContour  2.480409
# 42  SaleCondition  2.455579
# 35     GarageQual  2.411164
# 25   BsmtFinType2  2.251343
# 19      ExterCond  2.132086
# 18      ExterQual  2.098299
# 9      Condition1  2.033463
# 13      RoofStyle  1.965919
# 0        MSZoning  1.876117
# 30    KitchenQual  1.794113
# 39          Fence  1.678237
# 21       BsmtQual  1.587107
# 23   BsmtExposure  1.423259
# 33     GarageType  1.382167
# 6       LotConfig  1.316618
# 3        LotShape  1.314476
# 20     Foundation  1.243020
# 17     MasVnrType  1.205975
# 32    FireplaceQu  1.031449
# 34   GarageFinish  0.845364
# 12     HouseStyle  0.738677
# 16    Exterior2nd  0.445217
# 24   BsmtFinType1  0.390419
# 15    Exterior1st  0.367595
# 27      HeatingQC  0.344371
# 8    Neighborhood  0.190756
# 5       Utilities  0.029062
# 11       BldgType  0.013591
# 7       LandSlope  0.000000

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(X_encoded, y)
importances = model.feature_importances_

rf_df = pd.DataFrame({'Feature': X.columns, 'Importance': importances})
rf_df.sort_values('Importance', ascending=False, inplace=True)

# %%
rf_df
# Out:
#           Feature  Importance
# 43      SalePrice    0.146519
# 8    Neighborhood    0.059989
# 24   BsmtFinType1    0.050269
# 16    Exterior2nd    0.044091
# 15    Exterior1st    0.042208
# 32    FireplaceQu    0.041531
# 12     HouseStyle    0.038143
# 23   BsmtExposure    0.035475
# 34   GarageFinish    0.033494
# 6       LotConfig    0.032116
# 17     MasVnrType    0.031568
# 27      HeatingQC    0.030739
# 3        LotShape    0.028931
# 33     GarageType    0.024403
# 21       BsmtQual    0.023124
# 13      RoofStyle    0.023052
# 39          Fence    0.022637
# 30    KitchenQual    0.021317
# 42  SaleCondition    0.021207
# 20     Foundation    0.020845
# 9      Condition1    0.020250
# 25   BsmtFinType2    0.019275
# 11       BldgType    0.017987
# 0        MSZoning    0.017484
# 41       SaleType    0.016376
# 18      ExterQual    0.015135
# 19      ExterCond    0.014595
# 22       BsmtCond    0.013397
# 4     LandContour    0.012876
# 31     Functional    0.011049
# 29     Electrical    0.009160
# 35     GarageQual    0.008436
# 37     PavedDrive    0.007932
# 2           Alley    0.007757
# 36     GarageCond    0.007662
# 7       LandSlope    0.007445
# 40    MiscFeature    0.006527
# 28     CentralAir    0.004523
# 26        Heating    0.003546
# 14       RoofMatl    0.002970
# 10     Condition2    0.002077
# 38         PoolQC    0.000925
# 1          Street    0.000807
# 5       Utilities    0.000153
