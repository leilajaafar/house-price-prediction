# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("/Users/rofa/Desktop/gitprojet/house-price-prediction/notebooks/data processing/cleantrain.csv")

# %%
df.head()
# Out:
#    Id  LotFrontage  LotArea  Street  LotShape  Utilities  LandSlope  \
# 0   1         65.0     8450       1         4          4          1
# 1   2         80.0     9600       1         4          4          1
# 2   3         68.0    11250       1         3          4          1
# 3   4         60.0     9550       1         3          4          1
# 4   5         84.0    14260       1         3          4          1
#
#   HouseStyle  OverallQual  OverallCond  ...  SaleType_WD  \
# 0     2Story            7            5  ...         True
# 1     1Story            6            8  ...         True
# 2     2Story            7            5  ...         True
# 3     2Story            7            5  ...         True
# 4     2Story            8            5  ...         True
#
#    SaleCondition_AdjLand  SaleCondition_Alloca  SaleCondition_Family  \
# 0                  False                 False                 False
# 1                  False                 False                 False
# ...

# %%
# Sélection juste des colonnes numériques
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns

# %%
scaler = StandardScaler()

# %%
# Appliquer la standardisation
df_standardized = df.copy()
df_standardized[colonnes_numeriques] = scaler.fit_transform(df[colonnes_numeriques])
# Out:
#          Id  LotFrontage   LotArea    Street  LotShape  Utilities  LandSlope  \
# 0 -1.730865    -0.231877 -0.207142  0.064238  0.701291    0.02618  -0.225716
# 1 -1.728492     0.437043 -0.091886  0.064238  0.701291    0.02618  -0.225716
# 2 -1.726120    -0.098093  0.073480  0.064238 -1.016637    0.02618  -0.225716
# 3 -1.723747    -0.454850 -0.096897  0.064238 -1.016637    0.02618  -0.225716
# 4 -1.721374     0.615421  0.375148  0.064238 -1.016637    0.02618  -0.225716
#
#   HouseStyle  OverallQual  OverallCond  ...  SaleType_WD  \
# 0     2Story     0.651479    -0.517200  ...         True
# 1     1Story    -0.071836     2.179628  ...         True
# 2     2Story     0.651479    -0.517200  ...         True
# 3     2Story     0.651479    -0.517200  ...         True
# 4     2Story     1.374795    -0.517200  ...         True
#
#    SaleCondition_AdjLand  SaleCondition_Alloca  SaleCondition_Family  \
# 0                  False                 False                 False
# ...

# %%
#Sauvegarder le résultat
df.to_csv("cleantrain_standardized.csv", index=False)
